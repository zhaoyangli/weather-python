# %%
import numpy as np
import sklearn
import sklearn.ensemble
import time
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
import sklearn.metrics
import pandas as pd
#from sklearn.inspection import DecisionBoundaryDisplay

# %%
def Train_Test(model, X_train, X_test, t_train, t_test): # For Classification
    model.fit(X_train, t_train)
    t_pred = model.predict(X_test)
    print(sklearn.metrics.accuracy_score(t_test, t_pred),(np.average(sklearn.model_selection.cross_val_score(model,X_train,t_train,cv=10))))
    print(sklearn.metrics.confusion_matrix(t_test, t_pred))
    return(sklearn.metrics.accuracy_score(t_test, t_pred))

def Train_Test1(model, X_train, X_test, t_train, t_test): #For Regression
    model.fit(X_train, t_train)
    t_pred = model.predict(X_test)
    #print(np.mean((t_pred - t_test) ** 2))
    print(sklearn.metrics.mean_squared_error(y_pred=t_pred,y_true=t_test))
    print(model.score(X_test, t_test))
    return model.score(X_test, t_test)

def Test_NN_Regression(data): #Best Score: 0.527485248781123 Best layer_size: [25, 7]
    print("Training the model with MLPRegressor")
    X, t = data[:, :-2], data[:, -2]
    best_score = 0
    best_layer_size = [0,0]
    for i in range(3,4):
        n_train = 1200 + i * 100
        print("training data: " + str(n_train) )
        X_train = X[0:n_train]
        t_train = t[0:n_train]
        X_test = X[n_train:]
        t_test = t[n_train:]
        for j in range (10,35,5):
            for k in range (5, 20, 2):
                print("training the data with NN with hidden-layer-size( " +str(j) +","+str(k) +")" )
                NN_regr = sklearn.neural_network.MLPRegressor(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(j, k),random_state=1, max_iter=10000)
                score= Train_Test1(NN_regr, X_train, X_test, t_train, t_test)
                if score > best_score:
                    best_score = score
                    best_layer_size = [j,k]
    print("Best Score: " + str(best_score) + "Best layer_size: " + str(best_layer_size))


def Test_NN_Classification(data): # Best(49,13) accuracy: 0.81  Slightly more time-consuming than RF
    print("Training the model with MLPClassifier")
    X, t = data[:, :-2], data[:, -1]
    best_score = 0
    best_layer_size = [0, 0]
    for i in range(3,4):
        n_train = 1200 + i * 100
        print("training data: " + str(n_train) )
        X_train = X[0:n_train]
        t_train = t[0:n_train]
        X_test = X[n_train:]
        t_test = t[n_train:]
        for j in range (10,50):
            for k in range (5, 20):
                print("training the data with NN with hidden-layer-size( " +str(j) +","+str(k) +")" )
                NN_class = sklearn.neural_network.MLPClassifier(solver='sgd', alpha=1e-5, hidden_layer_sizes=(j, k),random_state=1, max_iter=10000)
                start_time = time.time()
                score = Train_Test(NN_class, X_train, X_test, t_train, t_test)
                end_time = time.time()
                print("Time used " + str(end_time - start_time))
                if score > best_score:
                    best_score = score
                    best_layer_size = [j, k]
    print("Best score "+ str(best_score)+ "Best layer_size: " + str(best_layer_size) )


def Test_RF_Classification(data): # Best(30,11) accuracy: 0.798
    print("Training the model with RandomForest")
    X, t = data[:, :-2], data[:, -1]
    best_score = 0
    best_n_estimator = 0
    best_n_maxDepth = 0
    best_time = 0
    for i in range(3,4):
        n_train = 1200 + i * 100
        print("training data: " + str(n_train) )
        X_train = X[0:n_train]
        t_train = t[0:n_train]
        X_test = X[n_train:]
        t_test = t[n_train:]
        for j in range (10,100,10):
            for k in range (1, 20, 2):
                print("training the data with NN with hidden-layer-size( " +str(j) +","+str(k) +")" )
                model = sklearn.ensemble.RandomForestClassifier(n_estimators=j, max_depth=k, random_state=0)
                start_time = time.time()
                score = Train_Test(model, X_train, X_test, t_train, t_test)
                end_time = time.time()
                print("Time used " + str(end_time - start_time))
                if score > best_score:
                    best_score = score
                    best_n_estimator = j
                    best_n_maxDepth = k
                    best_time = end_time - start_time
    print("Best score " + str(best_score) + "Best n_estimator: " + str(best_n_estimator) + "Best max_Depth " + str(best_n_maxDepth) + "Best Time " + str(best_time))

def loadData(file_name):
    with open(f"../data/{file_name}") as file:
        data=pd.read_csv(file)
        return data.to_numpy()

# %%
# data = np.loadtxt('../data/augmented_data.csv', delimiter=',', skiprows=1, usecols = range(5,17))
# X,t = data[:, :-2], data[:, -1]
# X_train = X[0:1500]
# t_train = t[0:1500]
# X_test = X[1500:]
# t_test = t[1500:]

# X1,t1 = data[:, :-2], data[:, -2]
# X1_train = X1[0:1500]
# t1_train = t1[0:1500]
# X1_test = X1[1500:]
# t1_test = t1[1500:]
dataset= loadData("augmented_data.csv")
y=dataset[:,1:3]
X=dataset[:,3:]
#X_train,X_test,y_train,y_test=sklearn.model_selection.train_test_split(X,y,random_state=0)
X_train=X[0:1500,:]
X_test=X[1500:,:]
X1_train=X_train
X1_test=X_test

t_train=y[0:1500,1]
t_test=y[1500:,1]
t1_train=y[0:1500:,0]
t1_test=y[1500:,0]
data=dataset

# %%
regr = sklearn.linear_model.LinearRegression()
SGD = sklearn.linear_model.SGDRegressor();
ada = sklearn.ensemble.AdaBoostRegressor(n_estimators = 500)

svm = sklearn.svm.SVC()
RF = sklearn.ensemble.RandomForestClassifier(n_estimators=100, max_depth=20, random_state=0)
NN = sklearn.neural_network.MLPClassifier(solver='sgd', alpha=1e-5, hidden_layer_sizes=(50, 15), random_state=1,max_iter = 10000)

#LR = sklearn.linear_model.LogisticRegression(random_state=0, solver='newton-cholesky', multi_class='ovr')
LR = sklearn.linear_model.LogisticRegression(random_state=0, solver='newton-cg', multi_class='ovr')
NN_regr = sklearn.neural_network.MLPRegressor(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(30, 8), random_state=1,max_iter = 10000)
Train_Test(svm,X_train, X_test, t_train, t_test)
Train_Test(RF,X_train, X_test, t_train, t_test)
Train_Test(LR,X_train, X_test, t_train, t_test)
Train_Test(NN,X_train, X_test, t_train, t_test)
Train_Test1(NN_regr,X1_train, X1_test, t1_train, t1_test)
Train_Test1(ada,X1_train, X1_test, t1_train, t1_test)


Test_NN_Regression(data)
Test_NN_Classification(data)
Test_RF_Classification(data)
# Out:
# 0.5540983606557377 0.5486666666666666
# [[118  37]
#  [ 99  51]]
# 0.6229508196721312 0.5546666666666666
# [[114  41]
#  [ 74  76]]
# 0.5573770491803278 0.5746666666666667
# [[109  46]
#  [ 89  61]]
# 0.5442622950819672 0.5373333333333333
# [[96 59]
#  [80 70]]
# 170.58100244532523
# -3.004745072644929
# 96.1804123006086
# -1.258035928527725
# Training the model with MLPRegressor
# training data: 1500
# training the data with NN with hidden-layer-size( 10,5)
# 0.25084621146097075
# -0.003913647442643553
# training the data with NN with hidden-layer-size( 10,7)
# 0.0002782962914604516
# 0.9988862281658446
# training the data with NN with hidden-layer-size( 10,9)
# 0.0001539127939957784
# 0.9993840243649347
# training the data with NN with hidden-layer-size( 10,11)
# 0.0013186723387295627
# 0.9947225307902978
# training the data with NN with hidden-layer-size( 10,13)
# 0.0006825355671572613
# 0.9972684188980036
# training the data with NN with hidden-layer-size( 10,15)
# 0.18260546716968493
# 0.26919318604973586
# training the data with NN with hidden-layer-size( 10,17)
# 0.0053266713623296635
# 0.9786820855497884
# training the data with NN with hidden-layer-size( 10,19)
# 0.2507800311473164
# -0.003648786675232829
# training the data with NN with hidden-layer-size( 15,5)
# 0.24999500856635493
# -0.0005070414681280777
# training the data with NN with hidden-layer-size( 15,7)
# 0.2499447584936521
# -0.00030593524660083027
# training the data with NN with hidden-layer-size( 15,9)
# 0.00786073918042469
# 0.9685404722827824
# training the data with NN with hidden-layer-size( 15,11)
# 0.004485485229938734
# 0.9820486033593594
# training the data with NN with hidden-layer-size( 15,13)
# 0.004419864993304406
# 0.982311222638008
# training the data with NN with hidden-layer-size( 15,15)
# 0.24996262742849987
# -0.0003774486549734668
# training the data with NN with hidden-layer-size( 15,17)
# 0.19011590689080096
# 0.23913559462584932
# training the data with NN with hidden-layer-size( 15,19)
# 0.1848137866018635
# 0.2603552530270886
# training the data with NN with hidden-layer-size( 20,5)
# 0.0017638303282819247
# 0.9929409604074847
# training the data with NN with hidden-layer-size( 20,7)
# 0.1829597626092981
# 0.26777525741137675
# training the data with NN with hidden-layer-size( 20,9)
# 0.18520446541913366
# 0.258791714179362
# training the data with NN with hidden-layer-size( 20,11)
# 0.0020515502810556896
# 0.9917894740623299
# training the data with NN with hidden-layer-size( 20,13)
# 0.0034687625942576984
# 0.9861176372254852
# training the data with NN with hidden-layer-size( 20,15)
# 0.19442582277308246
# 0.22188684548847026
# training the data with NN with hidden-layer-size( 20,17)
# 0.006781810707391192
# 0.9728584606326336
# training the data with NN with hidden-layer-size( 20,19)
# 0.18283389882021564
# 0.2682789778974978
# training the data with NN with hidden-layer-size( 25,5)
# 0.003638458109799285
# 0.9854384974331407
# training the data with NN with hidden-layer-size( 25,7)
# 0.008261290693405516
# 0.9669374218398705
# training the data with NN with hidden-layer-size( 25,9)
# 0.1915008349293721
# 0.23359296294506804
# training the data with NN with hidden-layer-size( 25,11)
# 0.0014660871802273038
# 0.9941325606633693
# training the data with NN with hidden-layer-size( 25,13)
# 0.003675547445334203
# 0.985290061904052
# training the data with NN with hidden-layer-size( 25,15)
# 0.15692584774064405
# 0.37196579822434117
# training the data with NN with hidden-layer-size( 25,17)
# 0.1502139753016246
# 0.3988274370833923
# training the data with NN with hidden-layer-size( 25,19)
# 0.0011499024647211393
# 0.9953979660651917
# training the data with NN with hidden-layer-size( 30,5)
# 0.15789142811743237
# 0.368101441205294
# training the data with NN with hidden-layer-size( 30,7)
# 0.0032555830984299086
# 0.9869708046062879
# training the data with NN with hidden-layer-size( 30,9)
# 0.187089320681893
# 0.25124831971979456
# training the data with NN with hidden-layer-size( 30,11)
# 0.0018716593883215155
# 0.9925094168560227
# training the data with NN with hidden-layer-size( 30,13)
# 0.19241757049317273
# 0.2299240881463004
# training the data with NN with hidden-layer-size( 30,15)
# 0.00239829792495651
# 0.9904017525181088
# training the data with NN with hidden-layer-size( 30,17)
# 0.0014071246847571469
# 0.9943685349423708
# training the data with NN with hidden-layer-size( 30,19)
# 0.0023643953111702016
# 0.9905374344423675
# Best Score: 0.9993840243649347Best layer_size: [10, 9]
# Training the model with MLPClassifier
# training data: 1500
# training the data with NN with hidden-layer-size( 10,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.317079544067383
# training the data with NN with hidden-layer-size( 10,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.4221737384796143
# training the data with NN with hidden-layer-size( 10,7)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.8853704929351807
# training the data with NN with hidden-layer-size( 10,8)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.0620157718658447
# training the data with NN with hidden-layer-size( 10,9)
# 0.5114754098360655 0.542
# [[156   0]
#  [149   0]]
# Time used 1.2484571933746338
# training the data with NN with hidden-layer-size( 10,10)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.6680169105529785
# training the data with NN with hidden-layer-size( 10,11)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.8580117225646973
# training the data with NN with hidden-layer-size( 10,12)
# 0.5114754098360655 0.5406666666666667
# [[156   0]
#  [149   0]]
# Time used 1.6172313690185547
# training the data with NN with hidden-layer-size( 10,13)
# 0.4885245901639344 0.4753333333333333
# [[  0 156]
#  [  0 149]]
# Time used 1.7735533714294434
# training the data with NN with hidden-layer-size( 10,14)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 1.5497560501098633
# training the data with NN with hidden-layer-size( 10,15)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.4216344356536865
# training the data with NN with hidden-layer-size( 10,16)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.5667691230773926
# training the data with NN with hidden-layer-size( 10,17)
# 0.5114754098360655 0.5406666666666667
# [[156   0]
#  [149   0]]
# Time used 1.9598803520202637
# training the data with NN with hidden-layer-size( 10,18)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.080068826675415
# training the data with NN with hidden-layer-size( 10,19)
# 0.5114754098360655 0.5413333333333334
# [[156   0]
#  [149   0]]
# Time used 1.859858512878418
# training the data with NN with hidden-layer-size( 11,5)
# 0.4885245901639344 0.5493333333333333
# [[  0 156]
#  [  0 149]]
# Time used 0.4943997859954834
# training the data with NN with hidden-layer-size( 11,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.9316458702087402
# training the data with NN with hidden-layer-size( 11,7)
# 0.5114754098360655 0.5046666666666667
# [[156   0]
#  [149   0]]
# Time used 7.140926837921143
# training the data with NN with hidden-layer-size( 11,8)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 1.2723088264465332
# training the data with NN with hidden-layer-size( 11,9)
# 0.5114754098360655 0.5366666666666667
# [[156   0]
#  [149   0]]
# Time used 2.43996524810791
# training the data with NN with hidden-layer-size( 11,10)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 0.4486832618713379
# training the data with NN with hidden-layer-size( 11,11)
# 0.5114754098360655 0.5373333333333333
# [[156   0]
#  [149   0]]
# Time used 2.2715766429901123
# training the data with NN with hidden-layer-size( 11,12)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 0.7520263195037842
# training the data with NN with hidden-layer-size( 11,13)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 0.9887588024139404
# training the data with NN with hidden-layer-size( 11,14)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.145946741104126
# training the data with NN with hidden-layer-size( 11,15)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.2102224826812744
# training the data with NN with hidden-layer-size( 11,16)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.5494880676269531
# training the data with NN with hidden-layer-size( 11,17)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 1.41017746925354
# training the data with NN with hidden-layer-size( 11,18)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.46945643424987793
# training the data with NN with hidden-layer-size( 11,19)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5041217803955078
# training the data with NN with hidden-layer-size( 12,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.712069272994995
# training the data with NN with hidden-layer-size( 12,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.6538901329040527
# training the data with NN with hidden-layer-size( 12,7)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.414398431777954
# training the data with NN with hidden-layer-size( 12,8)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 2.794907331466675
# training the data with NN with hidden-layer-size( 12,9)
# 0.5114754098360655 0.5246666666666667
# [[156   0]
#  [149   0]]
# Time used 2.08199405670166
# training the data with NN with hidden-layer-size( 12,10)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.5553092956542969
# training the data with NN with hidden-layer-size( 12,11)
# 0.4885245901639344 0.502
# [[  0 156]
#  [  0 149]]
# Time used 1.9190285205841064
# training the data with NN with hidden-layer-size( 12,12)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.540631055831909
# training the data with NN with hidden-layer-size( 12,13)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.6791834831237793
# training the data with NN with hidden-layer-size( 12,14)
# 0.5114754098360655 0.5406666666666667
# [[156   0]
#  [149   0]]
# Time used 0.8881597518920898
# training the data with NN with hidden-layer-size( 12,15)
# 0.5114754098360655 0.542
# [[156   0]
#  [149   0]]
# Time used 4.03155517578125
# training the data with NN with hidden-layer-size( 12,16)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 1.3220782279968262
# training the data with NN with hidden-layer-size( 12,17)
# 0.5114754098360655 0.5406666666666667
# [[156   0]
#  [149   0]]
# Time used 0.919003963470459
# training the data with NN with hidden-layer-size( 12,18)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.7344341278076172
# training the data with NN with hidden-layer-size( 12,19)
# 0.5114754098360655 0.5406666666666667
# [[156   0]
#  [149   0]]
# Time used 1.6685655117034912
# training the data with NN with hidden-layer-size( 13,5)
# 0.49508196721311476 0.5413333333333334
# [[  2 154]
#  [  0 149]]
# Time used 2.082735538482666
# training the data with NN with hidden-layer-size( 13,6)
# 0.4918032786885246 0.5506666666666666
# [[  1 155]
#  [  0 149]]
# Time used 2.340350866317749
# training the data with NN with hidden-layer-size( 13,7)
# 0.5114754098360655 0.5313333333333333
# [[156   0]
#  [149   0]]
# Time used 1.0829732418060303
# training the data with NN with hidden-layer-size( 13,8)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 0.7876312732696533
# training the data with NN with hidden-layer-size( 13,9)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.8901157379150391
# training the data with NN with hidden-layer-size( 13,10)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.9678633213043213
# training the data with NN with hidden-layer-size( 13,11)
# 0.5114754098360655 0.5413333333333334
# [[156   0]
#  [149   0]]
# Time used 1.6636590957641602
# training the data with NN with hidden-layer-size( 13,12)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 0.9097263813018799
# training the data with NN with hidden-layer-size( 13,13)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.2288188934326172
# training the data with NN with hidden-layer-size( 13,14)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 2.306756019592285
# training the data with NN with hidden-layer-size( 13,15)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.8215928077697754
# training the data with NN with hidden-layer-size( 13,16)
# 0.5114754098360655 0.5413333333333334
# [[156   0]
#  [149   0]]
# Time used 0.8842542171478271
# training the data with NN with hidden-layer-size( 13,17)
# 0.5114754098360655 0.5206666666666667
# [[156   0]
#  [149   0]]
# Time used 1.735069751739502
# training the data with NN with hidden-layer-size( 13,18)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.4958062171936035
# training the data with NN with hidden-layer-size( 13,19)
# 0.4885245901639344 0.5006666666666667
# [[  0 156]
#  [  0 149]]
# Time used 2.2272653579711914
# training the data with NN with hidden-layer-size( 14,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.430851936340332
# training the data with NN with hidden-layer-size( 14,6)
# 0.5114754098360655 0.5446666666666667
# [[156   0]
#  [149   0]]
# Time used 1.332050085067749
# training the data with NN with hidden-layer-size( 14,7)
# 0.5114754098360655 0.538
# [[156   0]
#  [149   0]]
# Time used 0.5647759437561035
# training the data with NN with hidden-layer-size( 14,8)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.218766212463379
# training the data with NN with hidden-layer-size( 14,9)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 1.1927456855773926
# training the data with NN with hidden-layer-size( 14,10)
# 0.5114754098360655 0.542
# [[156   0]
#  [149   0]]
# Time used 0.7407844066619873
# training the data with NN with hidden-layer-size( 14,11)
# 0.5114754098360655 0.542
# [[156   0]
#  [149   0]]
# Time used 2.368478298187256
# training the data with NN with hidden-layer-size( 14,12)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.4958076477050781
# training the data with NN with hidden-layer-size( 14,13)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 0.8497591018676758
# training the data with NN with hidden-layer-size( 14,14)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.8157193660736084
# training the data with NN with hidden-layer-size( 14,15)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.6484837532043457
# training the data with NN with hidden-layer-size( 14,16)
# 0.5114754098360655 0.5446666666666667
# [[156   0]
#  [149   0]]
# Time used 1.9686920642852783
# training the data with NN with hidden-layer-size( 14,17)
# 0.5114754098360655 0.5453333333333333
# [[156   0]
#  [149   0]]
# Time used 0.46756458282470703
# training the data with NN with hidden-layer-size( 14,18)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 0.4694550037384033
# training the data with NN with hidden-layer-size( 14,19)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 1.3044798374176025
# training the data with NN with hidden-layer-size( 15,5)
# 0.5114754098360655 0.5406666666666667
# [[156   0]
#  [149   0]]
# Time used 3.0469582080841064
# training the data with NN with hidden-layer-size( 15,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.43873167037963867
# training the data with NN with hidden-layer-size( 15,7)
# 0.5114754098360655 0.516
# [[156   0]
#  [149   0]]
# Time used 6.9218761920928955
# training the data with NN with hidden-layer-size( 15,8)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.9022915363311768
# training the data with NN with hidden-layer-size( 15,9)
# 0.5114754098360655 0.5153333333333333
# [[156   0]
#  [149   0]]
# Time used 3.632364273071289
# training the data with NN with hidden-layer-size( 15,10)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 1.942857027053833
# training the data with NN with hidden-layer-size( 15,11)
# 0.5114754098360655 0.508
# [[156   0]
#  [149   0]]
# Time used 4.12333345413208
# training the data with NN with hidden-layer-size( 15,12)
# 0.5114754098360655 0.5166666666666667
# [[156   0]
#  [149   0]]
# Time used 2.851346015930176
# training the data with NN with hidden-layer-size( 15,13)
# 0.5114754098360655 0.5333333333333334
# [[156   0]
#  [149   0]]
# Time used 4.6603102684021
# training the data with NN with hidden-layer-size( 15,14)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 2.8114378452301025
# training the data with NN with hidden-layer-size( 15,15)
# 0.5114754098360655 0.5373333333333333
# [[156   0]
#  [149   0]]
# Time used 2.772254467010498
# training the data with NN with hidden-layer-size( 15,16)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.0851263999938965
# training the data with NN with hidden-layer-size( 15,17)
# 0.5114754098360655 0.538
# [[156   0]
#  [149   0]]
# Time used 1.799631118774414
# training the data with NN with hidden-layer-size( 15,18)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 0.6558008193969727
# training the data with NN with hidden-layer-size( 15,19)
# 0.5114754098360655 0.538
# [[156   0]
#  [149   0]]
# Time used 0.6392776966094971
# training the data with NN with hidden-layer-size( 16,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.5853939056396484
# training the data with NN with hidden-layer-size( 16,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.47534656524658203
# training the data with NN with hidden-layer-size( 16,7)
# 0.5114754098360655 0.5166666666666667
# [[156   0]
#  [149   0]]
# Time used 1.5958361625671387
# training the data with NN with hidden-layer-size( 16,8)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 0.47729992866516113
# training the data with NN with hidden-layer-size( 16,9)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.6083898544311523
# training the data with NN with hidden-layer-size( 16,10)
# 0.5114754098360655 0.5193333333333333
# [[156   0]
#  [149   0]]
# Time used 3.3030669689178467
# training the data with NN with hidden-layer-size( 16,11)
# 0.5114754098360655 0.538
# [[156   0]
#  [149   0]]
# Time used 1.5915875434875488
# training the data with NN with hidden-layer-size( 16,12)
# 0.5114754098360655 0.5406666666666667
# [[156   0]
#  [149   0]]
# Time used 0.9847824573516846
# training the data with NN with hidden-layer-size( 16,13)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 1.5800197124481201
# training the data with NN with hidden-layer-size( 16,14)
# 0.5114754098360655 0.5313333333333333
# [[156   0]
#  [149   0]]
# Time used 1.3600730895996094
# training the data with NN with hidden-layer-size( 16,15)
# 0.5114754098360655 0.534
# [[156   0]
#  [149   0]]
# Time used 2.325144052505493
# training the data with NN with hidden-layer-size( 16,16)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5866355895996094
# training the data with NN with hidden-layer-size( 16,17)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.748594045639038
# training the data with NN with hidden-layer-size( 16,18)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5172836780548096
# training the data with NN with hidden-layer-size( 16,19)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5192818641662598
# training the data with NN with hidden-layer-size( 17,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.735015392303467
# training the data with NN with hidden-layer-size( 17,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.8574395179748535
# training the data with NN with hidden-layer-size( 17,7)
# 0.5114754098360655 0.554
# [[156   0]
#  [149   0]]
# Time used 1.837482213973999
# training the data with NN with hidden-layer-size( 17,8)
# 0.5114754098360655 0.5406666666666667
# [[156   0]
#  [149   0]]
# Time used 2.3714818954467773
# training the data with NN with hidden-layer-size( 17,9)
# 0.5114754098360655 0.51
# [[156   0]
#  [149   0]]
# Time used 1.7578487396240234
# training the data with NN with hidden-layer-size( 17,10)
# 0.5114754098360655 0.542
# [[156   0]
#  [149   0]]
# Time used 0.6737987995147705
# training the data with NN with hidden-layer-size( 17,11)
# 0.5114754098360655 0.5426666666666666
# [[156   0]
#  [149   0]]
# Time used 1.5352685451507568
# training the data with NN with hidden-layer-size( 17,12)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.870732069015503
# training the data with NN with hidden-layer-size( 17,13)
# 0.5114754098360655 0.5313333333333333
# [[156   0]
#  [149   0]]
# Time used 2.1784703731536865
# training the data with NN with hidden-layer-size( 17,14)
# 0.5114754098360655 0.5253333333333334
# [[156   0]
#  [149   0]]
# Time used 1.1600847244262695
# training the data with NN with hidden-layer-size( 17,15)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 1.5792438983917236
# training the data with NN with hidden-layer-size( 17,16)
# 0.5114754098360655 0.558
# [[156   0]
#  [149   0]]
# Time used 3.3258190155029297
# training the data with NN with hidden-layer-size( 17,17)
# 0.5114754098360655 0.492
# [[156   0]
#  [149   0]]
# Time used 1.335674524307251
# training the data with NN with hidden-layer-size( 17,18)
# 0.5114754098360655 0.5306666666666666
# [[156   0]
#  [149   0]]
# Time used 1.5357506275177002
# training the data with NN with hidden-layer-size( 17,19)
# 0.5114754098360655 0.5086666666666667
# [[156   0]
#  [149   0]]
# Time used 4.123087406158447
# training the data with NN with hidden-layer-size( 18,5)
# 0.5114754098360655 0.5406666666666667
# [[156   0]
#  [149   0]]
# Time used 0.4235837459564209
# training the data with NN with hidden-layer-size( 18,6)
# 0.5114754098360655 0.5346666666666666
# [[156   0]
#  [149   0]]
# Time used 1.277773380279541
# training the data with NN with hidden-layer-size( 18,7)
# 0.5114754098360655 0.506
# [[156   0]
#  [149   0]]
# Time used 4.479982137680054
# training the data with NN with hidden-layer-size( 18,8)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.41924333572387695
# training the data with NN with hidden-layer-size( 18,9)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 0.7528529167175293
# training the data with NN with hidden-layer-size( 18,10)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.823197841644287
# training the data with NN with hidden-layer-size( 18,11)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.124351978302002
# training the data with NN with hidden-layer-size( 18,12)
# 0.5114754098360655 0.5306666666666666
# [[156   0]
#  [149   0]]
# Time used 2.2389795780181885
# training the data with NN with hidden-layer-size( 18,13)
# 0.5114754098360655 0.5333333333333334
# [[156   0]
#  [149   0]]
# Time used 1.3683664798736572
# training the data with NN with hidden-layer-size( 18,14)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.534585952758789
# training the data with NN with hidden-layer-size( 18,15)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.8979194164276123
# training the data with NN with hidden-layer-size( 18,16)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.8252708911895752
# training the data with NN with hidden-layer-size( 18,17)
# 0.5114754098360655 0.538
# [[156   0]
#  [149   0]]
# Time used 1.7784748077392578
# training the data with NN with hidden-layer-size( 18,18)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 0.6988534927368164
# training the data with NN with hidden-layer-size( 18,19)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 1.4059455394744873
# training the data with NN with hidden-layer-size( 19,5)
# 0.5114754098360655 0.5453333333333333
# [[156   0]
#  [149   0]]
# Time used 3.2741098403930664
# training the data with NN with hidden-layer-size( 19,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.529865264892578
# training the data with NN with hidden-layer-size( 19,7)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.4842824935913086
# training the data with NN with hidden-layer-size( 19,8)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 0.5626437664031982
# training the data with NN with hidden-layer-size( 19,9)
# 0.5114754098360655 0.532
# [[156   0]
#  [149   0]]
# Time used 2.4683659076690674
# training the data with NN with hidden-layer-size( 19,10)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.7934873104095459
# training the data with NN with hidden-layer-size( 19,11)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.1889915466308594
# training the data with NN with hidden-layer-size( 19,12)
# 0.5114754098360655 0.544
# [[156   0]
#  [149   0]]
# Time used 1.152655839920044
# training the data with NN with hidden-layer-size( 19,13)
# 0.4885245901639344 0.5393333333333333
# [[  0 156]
#  [  0 149]]
# Time used 3.2419233322143555
# training the data with NN with hidden-layer-size( 19,14)
# 0.5114754098360655 0.534
# [[156   0]
#  [149   0]]
# Time used 2.5644729137420654
# training the data with NN with hidden-layer-size( 19,15)
# 0.5114754098360655 0.5273333333333333
# [[156   0]
#  [149   0]]
# Time used 2.491748571395874
# training the data with NN with hidden-layer-size( 19,16)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.7227799892425537
# training the data with NN with hidden-layer-size( 19,17)
# 0.5704918032786885 0.542
# [[144  12]
#  [119  30]]
# Time used 1.760904312133789
# training the data with NN with hidden-layer-size( 19,18)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 1.5859997272491455
# training the data with NN with hidden-layer-size( 19,19)
# 0.5114754098360655 0.524
# [[156   0]
#  [149   0]]
# Time used 1.6376094818115234
# training the data with NN with hidden-layer-size( 20,5)
# 0.5114754098360655 0.5426666666666666
# [[156   0]
#  [149   0]]
# Time used 1.124699354171753
# training the data with NN with hidden-layer-size( 20,6)
# 0.5114754098360655 0.5413333333333334
# [[156   0]
#  [149   0]]
# Time used 1.437211513519287
# training the data with NN with hidden-layer-size( 20,7)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.926086187362671
# training the data with NN with hidden-layer-size( 20,8)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.5046281814575195
# training the data with NN with hidden-layer-size( 20,9)
# 0.5114754098360655 0.5426666666666666
# [[156   0]
#  [149   0]]
# Time used 1.3761584758758545
# training the data with NN with hidden-layer-size( 20,10)
# 0.5114754098360655 0.542
# [[156   0]
#  [149   0]]
# Time used 0.5492763519287109
# training the data with NN with hidden-layer-size( 20,11)
# 0.4885245901639344 0.526
# [[  0 156]
#  [  0 149]]
# Time used 2.6104445457458496
# training the data with NN with hidden-layer-size( 20,12)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.6968629360198975
# training the data with NN with hidden-layer-size( 20,13)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.343776226043701
# training the data with NN with hidden-layer-size( 20,14)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 0.5572960376739502
# training the data with NN with hidden-layer-size( 20,15)
# 0.5114754098360655 0.542
# [[156   0]
#  [149   0]]
# Time used 2.0115253925323486
# training the data with NN with hidden-layer-size( 20,16)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 1.6045150756835938
# training the data with NN with hidden-layer-size( 20,17)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.99715256690979
# training the data with NN with hidden-layer-size( 20,18)
# 0.5114754098360655 0.542
# [[156   0]
#  [149   0]]
# Time used 1.4826428890228271
# training the data with NN with hidden-layer-size( 20,19)
# 0.5114754098360655 0.5406666666666667
# [[156   0]
#  [149   0]]
# Time used 3.618459939956665
# training the data with NN with hidden-layer-size( 21,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.8746933937072754
# training the data with NN with hidden-layer-size( 21,6)
# 0.4885245901639344 0.5126666666666667
# [[  0 156]
#  [  0 149]]
# Time used 3.69865345954895
# training the data with NN with hidden-layer-size( 21,7)
# 0.5114754098360655 0.542
# [[156   0]
#  [149   0]]
# Time used 0.519787073135376
# training the data with NN with hidden-layer-size( 21,8)
# 0.5114754098360655 0.5033333333333333
# [[156   0]
#  [149   0]]
# Time used 2.6246910095214844
# training the data with NN with hidden-layer-size( 21,9)
# 0.5114754098360655 0.5406666666666667
# [[156   0]
#  [149   0]]
# Time used 2.4164350032806396
# training the data with NN with hidden-layer-size( 21,10)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.4820399284362793
# training the data with NN with hidden-layer-size( 21,11)
# 0.4885245901639344 0.48666666666666664
# [[  0 156]
#  [  0 149]]
# Time used 0.8363065719604492
# training the data with NN with hidden-layer-size( 21,12)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.9057488441467285
# training the data with NN with hidden-layer-size( 21,13)
# 0.5114754098360655 0.538
# [[156   0]
#  [149   0]]
# Time used 0.9887251853942871
# training the data with NN with hidden-layer-size( 21,14)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.5725667476654053
# training the data with NN with hidden-layer-size( 21,15)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 3.26720929145813
# training the data with NN with hidden-layer-size( 21,16)
# 0.5114754098360655 0.5246666666666667
# [[156   0]
#  [149   0]]
# Time used 1.5049903392791748
# training the data with NN with hidden-layer-size( 21,17)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.233694314956665
# training the data with NN with hidden-layer-size( 21,18)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 0.914043664932251
# training the data with NN with hidden-layer-size( 21,19)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 0.9091670513153076
# training the data with NN with hidden-layer-size( 22,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 4.013741493225098
# training the data with NN with hidden-layer-size( 22,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.509453773498535
# training the data with NN with hidden-layer-size( 22,7)
# 0.5114754098360655 0.5426666666666666
# [[156   0]
#  [149   0]]
# Time used 2.21333646774292
# training the data with NN with hidden-layer-size( 22,8)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.48514556884765625
# training the data with NN with hidden-layer-size( 22,9)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.44212841987609863
# training the data with NN with hidden-layer-size( 22,10)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.247612953186035
# training the data with NN with hidden-layer-size( 22,11)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.429344892501831
# training the data with NN with hidden-layer-size( 22,12)
# 0.5114754098360655 0.5426666666666666
# [[156   0]
#  [149   0]]
# Time used 1.130876064300537
# training the data with NN with hidden-layer-size( 22,13)
# 0.5114754098360655 0.5173333333333334
# [[156   0]
#  [149   0]]
# Time used 4.700375318527222
# training the data with NN with hidden-layer-size( 22,14)
# 0.5114754098360655 0.542
# [[156   0]
#  [149   0]]
# Time used 1.0199189186096191
# training the data with NN with hidden-layer-size( 22,15)
# 0.5114754098360655 0.5466666666666666
# [[156   0]
#  [149   0]]
# Time used 0.6551287174224854
# training the data with NN with hidden-layer-size( 22,16)
# 0.5114754098360655 0.5506666666666667
# [[156   0]
#  [149   0]]
# Time used 1.5875461101531982
# training the data with NN with hidden-layer-size( 22,17)
# 0.5114754098360655 0.5593333333333333
# [[156   0]
#  [149   0]]
# Time used 1.3507821559906006
# training the data with NN with hidden-layer-size( 22,18)
# 0.5114754098360655 0.5406666666666667
# [[156   0]
#  [149   0]]
# Time used 0.8976736068725586
# training the data with NN with hidden-layer-size( 22,19)
# 0.5147540983606558 0.5493333333333335
# [[156   0]
#  [148   1]]
# Time used 1.4249579906463623
# training the data with NN with hidden-layer-size( 23,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.4937334060668945
# training the data with NN with hidden-layer-size( 23,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.8014583587646484
# training the data with NN with hidden-layer-size( 23,7)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5358231067657471
# training the data with NN with hidden-layer-size( 23,8)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.229665756225586
# training the data with NN with hidden-layer-size( 23,9)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 2.410259485244751
# training the data with NN with hidden-layer-size( 23,10)
# 0.5114754098360655 0.5313333333333333
# [[156   0]
#  [149   0]]
# Time used 2.270322322845459
# training the data with NN with hidden-layer-size( 23,11)
# 0.4885245901639344 0.5386666666666666
# [[  0 156]
#  [  0 149]]
# Time used 2.422430992126465
# training the data with NN with hidden-layer-size( 23,12)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.9594573974609375
# training the data with NN with hidden-layer-size( 23,13)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.7529563903808594
# training the data with NN with hidden-layer-size( 23,14)
# 0.5114754098360655 0.5426666666666666
# [[156   0]
#  [149   0]]
# Time used 1.185030221939087
# training the data with NN with hidden-layer-size( 23,15)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.5260517597198486
# training the data with NN with hidden-layer-size( 23,16)
# 0.5114754098360655 0.5413333333333334
# [[156   0]
#  [149   0]]
# Time used 2.5079312324523926
# training the data with NN with hidden-layer-size( 23,17)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 1.5331971645355225
# training the data with NN with hidden-layer-size( 23,18)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.2853455543518066
# training the data with NN with hidden-layer-size( 23,19)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 0.7695930004119873
# training the data with NN with hidden-layer-size( 24,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.749528646469116
# training the data with NN with hidden-layer-size( 24,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.4658117294311523
# training the data with NN with hidden-layer-size( 24,7)
# 0.5114754098360655 0.5326666666666667
# [[156   0]
#  [149   0]]
# Time used 1.7445158958435059
# training the data with NN with hidden-layer-size( 24,8)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.3327138423919678
# training the data with NN with hidden-layer-size( 24,9)
# 0.4885245901639344 0.5313333333333333
# [[  0 156]
#  [  0 149]]
# Time used 1.4511041641235352
# training the data with NN with hidden-layer-size( 24,10)
# 0.5114754098360655 0.5473333333333332
# [[156   0]
#  [149   0]]
# Time used 0.8945586681365967
# training the data with NN with hidden-layer-size( 24,11)
# 0.5114754098360655 0.484
# [[156   0]
#  [149   0]]
# Time used 1.869286060333252
# training the data with NN with hidden-layer-size( 24,12)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.817394256591797
# training the data with NN with hidden-layer-size( 24,13)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5295693874359131
# training the data with NN with hidden-layer-size( 24,14)
# 0.5049180327868853 0.5373333333333334
# [[ 47 109]
#  [ 42 107]]
# Time used 1.571493148803711
# training the data with NN with hidden-layer-size( 24,15)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.6217479705810547
# training the data with NN with hidden-layer-size( 24,16)
# 0.5114754098360655 0.542
# [[156   0]
#  [149   0]]
# Time used 0.5807554721832275
# training the data with NN with hidden-layer-size( 24,17)
# 0.5114754098360655 0.538
# [[156   0]
#  [149   0]]
# Time used 0.6011538505554199
# training the data with NN with hidden-layer-size( 24,18)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 1.1155531406402588
# training the data with NN with hidden-layer-size( 24,19)
# 0.5114754098360655 0.538
# [[156   0]
#  [149   0]]
# Time used 1.2273731231689453
# training the data with NN with hidden-layer-size( 25,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.538722515106201
# training the data with NN with hidden-layer-size( 25,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5471756458282471
# training the data with NN with hidden-layer-size( 25,7)
# 0.4885245901639344 0.5233333333333333
# [[  0 156]
#  [  0 149]]
# Time used 3.2004971504211426
# training the data with NN with hidden-layer-size( 25,8)
# 0.5114754098360655 0.55
# [[156   0]
#  [149   0]]
# Time used 1.845871925354004
# training the data with NN with hidden-layer-size( 25,9)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.7235536575317383
# training the data with NN with hidden-layer-size( 25,10)
# 0.5114754098360655 0.5233333333333333
# [[156   0]
#  [149   0]]
# Time used 3.6763718128204346
# training the data with NN with hidden-layer-size( 25,11)
# 0.5114754098360655 0.5439999999999999
# [[156   0]
#  [149   0]]
# Time used 3.760810375213623
# training the data with NN with hidden-layer-size( 25,12)
# 0.5114754098360655 0.5593333333333333
# [[156   0]
#  [149   0]]
# Time used 3.817485809326172
# training the data with NN with hidden-layer-size( 25,13)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.8812928199768066
# training the data with NN with hidden-layer-size( 25,14)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.0662989616394043
# training the data with NN with hidden-layer-size( 25,15)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.7388660907745361
# training the data with NN with hidden-layer-size( 25,16)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.48467183113098145
# training the data with NN with hidden-layer-size( 25,17)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.0580244064331055
# training the data with NN with hidden-layer-size( 25,18)
# 0.4885245901639344 0.5393333333333333
# [[  0 156]
#  [  0 149]]
# Time used 3.478569984436035
# training the data with NN with hidden-layer-size( 25,19)
# 0.5114754098360655 0.542
# [[156   0]
#  [149   0]]
# Time used 1.9189181327819824
# training the data with NN with hidden-layer-size( 26,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.555461883544922
# training the data with NN with hidden-layer-size( 26,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.7148218154907227
# training the data with NN with hidden-layer-size( 26,7)
# 0.4885245901639344 0.5326666666666667
# [[  0 156]
#  [  0 149]]
# Time used 1.5085694789886475
# training the data with NN with hidden-layer-size( 26,8)
# 0.5114754098360655 0.49466666666666664
# [[156   0]
#  [149   0]]
# Time used 2.120941400527954
# training the data with NN with hidden-layer-size( 26,9)
# 0.5114754098360655 0.554
# [[156   0]
#  [149   0]]
# Time used 1.0915420055389404
# training the data with NN with hidden-layer-size( 26,10)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5572946071624756
# training the data with NN with hidden-layer-size( 26,11)
# 0.5114754098360655 0.538
# [[156   0]
#  [149   0]]
# Time used 1.6698462963104248
# training the data with NN with hidden-layer-size( 26,12)
# 0.5114754098360655 0.55
# [[156   0]
#  [149   0]]
# Time used 1.1107618808746338
# training the data with NN with hidden-layer-size( 26,13)
# 0.5114754098360655 0.5493333333333333
# [[156   0]
#  [149   0]]
# Time used 2.8724496364593506
# training the data with NN with hidden-layer-size( 26,14)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.595043420791626
# training the data with NN with hidden-layer-size( 26,15)
# 0.4885245901639344 0.5153333333333333
# [[  0 156]
#  [  0 149]]
# Time used 3.258270740509033
# training the data with NN with hidden-layer-size( 26,16)
# 0.5114754098360655 0.5406666666666667
# [[156   0]
#  [149   0]]
# Time used 1.3585913181304932
# training the data with NN with hidden-layer-size( 26,17)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.8178865909576416
# training the data with NN with hidden-layer-size( 26,18)
# 0.5114754098360655 0.5413333333333334
# [[156   0]
#  [149   0]]
# Time used 0.7945024967193604
# training the data with NN with hidden-layer-size( 26,19)
# 0.5114754098360655 0.5406666666666667
# [[156   0]
#  [149   0]]
# Time used 0.882819414138794
# training the data with NN with hidden-layer-size( 27,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.435796022415161
# training the data with NN with hidden-layer-size( 27,6)
# 0.5114754098360655 0.532
# [[156   0]
#  [149   0]]
# Time used 4.135067939758301
# training the data with NN with hidden-layer-size( 27,7)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.1248834133148193
# training the data with NN with hidden-layer-size( 27,8)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.3875174522399902
# training the data with NN with hidden-layer-size( 27,9)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.1709651947021484
# training the data with NN with hidden-layer-size( 27,10)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.9150142669677734
# training the data with NN with hidden-layer-size( 27,11)
# 0.4885245901639344 0.542
# [[  0 156]
#  [  0 149]]
# Time used 2.570711851119995
# training the data with NN with hidden-layer-size( 27,12)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5158333778381348
# training the data with NN with hidden-layer-size( 27,13)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.8237435817718506
# training the data with NN with hidden-layer-size( 27,14)
# 0.5114754098360655 0.5433333333333333
# [[156   0]
#  [149   0]]
# Time used 1.296060562133789
# training the data with NN with hidden-layer-size( 27,15)
# 0.5114754098360655 0.5346666666666666
# [[156   0]
#  [149   0]]
# Time used 2.122067928314209
# training the data with NN with hidden-layer-size( 27,16)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5016634464263916
# training the data with NN with hidden-layer-size( 27,17)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.5495305061340332
# training the data with NN with hidden-layer-size( 27,18)
# 0.5114754098360655 0.5426666666666666
# [[156   0]
#  [149   0]]
# Time used 1.5470647811889648
# training the data with NN with hidden-layer-size( 27,19)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.180532693862915
# training the data with NN with hidden-layer-size( 28,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 4.060026407241821
# training the data with NN with hidden-layer-size( 28,6)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 2.41609263420105
# training the data with NN with hidden-layer-size( 28,7)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.461580514907837
# training the data with NN with hidden-layer-size( 28,8)
# 0.5114754098360655 0.532
# [[156   0]
#  [149   0]]
# Time used 1.77754545211792
# training the data with NN with hidden-layer-size( 28,9)
# 0.4852459016393443 0.5313333333333333
# [[  2 154]
#  [  3 146]]
# Time used 2.5206494331359863
# training the data with NN with hidden-layer-size( 28,10)
# 0.4885245901639344 0.536
# [[  0 156]
#  [  0 149]]
# Time used 2.444519281387329
# training the data with NN with hidden-layer-size( 28,11)
# 0.5114754098360655 0.5313333333333333
# [[156   0]
#  [149   0]]
# Time used 1.492570400238037
# training the data with NN with hidden-layer-size( 28,12)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5442183017730713
# training the data with NN with hidden-layer-size( 28,13)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.1644084453582764
# training the data with NN with hidden-layer-size( 28,14)
# 0.5114754098360655 0.544
# [[156   0]
#  [149   0]]
# Time used 2.0292437076568604
# training the data with NN with hidden-layer-size( 28,15)
# 0.5114754098360655 0.5473333333333333
# [[156   0]
#  [149   0]]
# Time used 2.4019341468811035
# training the data with NN with hidden-layer-size( 28,16)
# 0.5114754098360655 0.5486666666666667
# [[156   0]
#  [149   0]]
# Time used 4.182251453399658
# training the data with NN with hidden-layer-size( 28,17)
# 0.5114754098360655 0.5246666666666667
# [[156   0]
#  [149   0]]
# Time used 1.9823672771453857
# training the data with NN with hidden-layer-size( 28,18)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.015235424041748
# training the data with NN with hidden-layer-size( 28,19)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.2706825733184814
# training the data with NN with hidden-layer-size( 29,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.027874708175659
# training the data with NN with hidden-layer-size( 29,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5153264999389648
# training the data with NN with hidden-layer-size( 29,7)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.9724583625793457
# training the data with NN with hidden-layer-size( 29,8)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.235609769821167
# training the data with NN with hidden-layer-size( 29,9)
# 0.5114754098360655 0.5233333333333333
# [[156   0]
#  [149   0]]
# Time used 3.3758127689361572
# training the data with NN with hidden-layer-size( 29,10)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.6796281337738037
# training the data with NN with hidden-layer-size( 29,11)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.611753225326538
# training the data with NN with hidden-layer-size( 29,12)
# 0.4885245901639344 0.49066666666666664
# [[  0 156]
#  [  0 149]]
# Time used 1.7612826824188232
# training the data with NN with hidden-layer-size( 29,13)
# 0.5114754098360655 0.5453333333333333
# [[156   0]
#  [149   0]]
# Time used 3.653856039047241
# training the data with NN with hidden-layer-size( 29,14)
# 0.5114754098360655 0.5333333333333333
# [[156   0]
#  [149   0]]
# Time used 1.5789873600006104
# training the data with NN with hidden-layer-size( 29,15)
# 0.5114754098360655 0.5513333333333333
# [[156   0]
#  [149   0]]
# Time used 0.9779515266418457
# training the data with NN with hidden-layer-size( 29,16)
# 0.5114754098360655 0.5473333333333332
# [[156   0]
#  [149   0]]
# Time used 2.193648338317871
# training the data with NN with hidden-layer-size( 29,17)
# 0.5114754098360655 0.526
# [[156   0]
#  [149   0]]
# Time used 2.87503981590271
# training the data with NN with hidden-layer-size( 29,18)
# 0.5114754098360655 0.5246666666666667
# [[156   0]
#  [149   0]]
# Time used 3.235309600830078
# training the data with NN with hidden-layer-size( 29,19)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.791534423828125
# training the data with NN with hidden-layer-size( 30,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.551086902618408
# training the data with NN with hidden-layer-size( 30,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.1682417392730713
# training the data with NN with hidden-layer-size( 30,7)
# 0.5114754098360655 0.5466666666666666
# [[156   0]
#  [149   0]]
# Time used 2.35937762260437
# training the data with NN with hidden-layer-size( 30,8)
# 0.5114754098360655 0.5313333333333333
# [[156   0]
#  [149   0]]
# Time used 2.053586959838867
# training the data with NN with hidden-layer-size( 30,9)
# ...
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.4961719512939453
# training the data with NN with hidden-layer-size( 35,16)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 4.299066781997681
# training the data with NN with hidden-layer-size( 35,17)
# 0.5114754098360655 0.542
# [[156   0]
#  [149   0]]
# Time used 1.8740298748016357
# training the data with NN with hidden-layer-size( 35,18)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 1.624380350112915
# training the data with NN with hidden-layer-size( 35,19)
# 0.5114754098360655 0.5413333333333334
# [[156   0]
#  [149   0]]
# Time used 1.008159875869751
# training the data with NN with hidden-layer-size( 36,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.9382989406585693
# training the data with NN with hidden-layer-size( 36,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.8871026039123535
# training the data with NN with hidden-layer-size( 36,7)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.5406033992767334
# training the data with NN with hidden-layer-size( 36,8)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.6902551651000977
# training the data with NN with hidden-layer-size( 36,9)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 4.315778732299805
# training the data with NN with hidden-layer-size( 36,10)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 4.177658319473267
# training the data with NN with hidden-layer-size( 36,11)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.5201964378356934
# training the data with NN with hidden-layer-size( 36,12)
# 0.4885245901639344 0.5253333333333333
# [[  0 156]
#  [  0 149]]
# Time used 0.9950859546661377
# training the data with NN with hidden-layer-size( 36,13)
# 0.5114754098360655 0.5153333333333333
# [[156   0]
#  [149   0]]
# Time used 2.6564412117004395
# training the data with NN with hidden-layer-size( 36,14)
# 0.4885245901639344 0.5393333333333333
# [[  0 156]
#  [  0 149]]
# Time used 2.0697944164276123
# training the data with NN with hidden-layer-size( 36,15)
# 0.5114754098360655 0.5226666666666666
# [[156   0]
#  [149   0]]
# Time used 1.9950175285339355
# training the data with NN with hidden-layer-size( 36,16)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.8555173873901367
# training the data with NN with hidden-layer-size( 36,17)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.6938464641571045
# training the data with NN with hidden-layer-size( 36,18)
# 0.5344262295081967 0.5286666666666667
# [[156   0]
#  [142   7]]
# Time used 1.927316665649414
# training the data with NN with hidden-layer-size( 36,19)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.6504671573638916
# training the data with NN with hidden-layer-size( 37,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.8987114429473877
# training the data with NN with hidden-layer-size( 37,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.8079121112823486
# training the data with NN with hidden-layer-size( 37,7)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.92192006111145
# training the data with NN with hidden-layer-size( 37,8)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.807744026184082
# training the data with NN with hidden-layer-size( 37,9)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.7865800857543945
# training the data with NN with hidden-layer-size( 37,10)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.885493516921997
# training the data with NN with hidden-layer-size( 37,11)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.1948649883270264
# training the data with NN with hidden-layer-size( 37,12)
# 0.5114754098360655 0.5306666666666666
# [[156   0]
#  [149   0]]
# Time used 2.106714963912964
# training the data with NN with hidden-layer-size( 37,13)
# 0.5114754098360655 0.4993333333333333
# [[156   0]
#  [149   0]]
# Time used 3.4643619060516357
# training the data with NN with hidden-layer-size( 37,14)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5401773452758789
# training the data with NN with hidden-layer-size( 37,15)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.05411696434021
# training the data with NN with hidden-layer-size( 37,16)
# 0.5114754098360655 0.5473333333333333
# [[156   0]
#  [149   0]]
# Time used 0.9486715793609619
# training the data with NN with hidden-layer-size( 37,17)
# 0.5114754098360655 0.5353333333333333
# [[156   0]
#  [149   0]]
# Time used 2.024412155151367
# training the data with NN with hidden-layer-size( 37,18)
# 0.5114754098360655 0.5433333333333333
# [[156   0]
#  [149   0]]
# Time used 2.9208502769470215
# training the data with NN with hidden-layer-size( 37,19)
# 0.4885245901639344 0.47400000000000003
# [[  0 156]
#  [  0 149]]
# Time used 1.1732244491577148
# training the data with NN with hidden-layer-size( 38,5)
# 0.5114754098360655 0.5373333333333333
# [[156   0]
#  [149   0]]
# Time used 1.3171665668487549
# training the data with NN with hidden-layer-size( 38,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5441768169403076
# training the data with NN with hidden-layer-size( 38,7)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.8013312816619873
# training the data with NN with hidden-layer-size( 38,8)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 3.857093572616577
# training the data with NN with hidden-layer-size( 38,9)
# 0.5114754098360655 0.4753333333333334
# [[156   0]
#  [149   0]]
# Time used 4.214552164077759
# training the data with NN with hidden-layer-size( 38,10)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 1.4889874458312988
# training the data with NN with hidden-layer-size( 38,11)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.994037389755249
# training the data with NN with hidden-layer-size( 38,12)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 4.603978633880615
# training the data with NN with hidden-layer-size( 38,13)
# 0.5114754098360655 0.538
# [[156   0]
#  [149   0]]
# Time used 3.824631690979004
# training the data with NN with hidden-layer-size( 38,14)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.5503737926483154
# training the data with NN with hidden-layer-size( 38,15)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.1861708164215088
# training the data with NN with hidden-layer-size( 38,16)
# 0.5114754098360655 0.5226666666666666
# [[156   0]
#  [149   0]]
# Time used 4.126922845840454
# training the data with NN with hidden-layer-size( 38,17)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.939924955368042
# training the data with NN with hidden-layer-size( 38,18)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.725797414779663
# training the data with NN with hidden-layer-size( 38,19)
# 0.5114754098360655 0.5253333333333334
# [[156   0]
#  [149   0]]
# Time used 2.1182892322540283
# training the data with NN with hidden-layer-size( 39,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 4.414621114730835
# training the data with NN with hidden-layer-size( 39,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5402677059173584
# training the data with NN with hidden-layer-size( 39,7)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.6524441242218018
# training the data with NN with hidden-layer-size( 39,8)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.340681552886963
# training the data with NN with hidden-layer-size( 39,9)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5641930103302002
# training the data with NN with hidden-layer-size( 39,10)
# 0.5114754098360655 0.5426666666666666
# [[156   0]
#  [149   0]]
# Time used 2.2968266010284424
# training the data with NN with hidden-layer-size( 39,11)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.884558916091919
# training the data with NN with hidden-layer-size( 39,12)
# 0.5114754098360655 0.5233333333333333
# [[156   0]
#  [149   0]]
# Time used 3.974456310272217
# training the data with NN with hidden-layer-size( 39,13)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.9173035621643066
# training the data with NN with hidden-layer-size( 39,14)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.0999536514282227
# training the data with NN with hidden-layer-size( 39,15)
# 0.5114754098360655 0.5333333333333334
# [[156   0]
#  [149   0]]
# Time used 3.228585720062256
# training the data with NN with hidden-layer-size( 39,16)
# 0.5114754098360655 0.534
# [[156   0]
#  [149   0]]
# Time used 2.0628316402435303
# training the data with NN with hidden-layer-size( 39,17)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5821342468261719
# training the data with NN with hidden-layer-size( 39,18)
# 0.4885245901639344 0.538
# [[  0 156]
#  [  0 149]]
# Time used 3.2660295963287354
# training the data with NN with hidden-layer-size( 39,19)
# 0.5114754098360655 0.5439999999999999
# [[156   0]
#  [149   0]]
# Time used 1.8741862773895264
# training the data with NN with hidden-layer-size( 40,5)
# 0.5114754098360655 0.5233333333333333
# [[156   0]
#  [149   0]]
# Time used 2.795668363571167
# training the data with NN with hidden-layer-size( 40,6)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.8461902141571045
# training the data with NN with hidden-layer-size( 40,7)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.5850884914398193
# training the data with NN with hidden-layer-size( 40,8)
# 0.5114754098360655 0.4993333333333333
# [[156   0]
#  [149   0]]
# Time used 2.816023826599121
# training the data with NN with hidden-layer-size( 40,9)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 0.5573956966400146
# training the data with NN with hidden-layer-size( 40,10)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.88146710395813
# training the data with NN with hidden-layer-size( 40,11)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.5358231067657471
# training the data with NN with hidden-layer-size( 40,12)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.8894083499908447
# training the data with NN with hidden-layer-size( 40,13)
# 0.5114754098360655 0.5233333333333333
# [[156   0]
#  [149   0]]
# Time used 3.187412977218628
# training the data with NN with hidden-layer-size( 40,14)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.928574562072754
# training the data with NN with hidden-layer-size( 40,15)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.2786152362823486
# training the data with NN with hidden-layer-size( 40,16)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.4588494300842285
# training the data with NN with hidden-layer-size( 40,17)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.7515194416046143
# training the data with NN with hidden-layer-size( 40,18)
# 0.5114754098360655 0.5293333333333333
# [[156   0]
#  [149   0]]
# Time used 3.250916004180908
# training the data with NN with hidden-layer-size( 40,19)
# 0.5114754098360655 0.5346666666666666
# [[156   0]
#  [149   0]]
# Time used 4.031221628189087
# training the data with NN with hidden-layer-size( 41,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.8181796073913574
# training the data with NN with hidden-layer-size( 41,6)
# 0.5114754098360655 0.5233333333333333
# [[156   0]
#  [149   0]]
# Time used 3.654085397720337
# training the data with NN with hidden-layer-size( 41,7)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.470911741256714
# training the data with NN with hidden-layer-size( 41,8)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 4.743880748748779
# training the data with NN with hidden-layer-size( 41,9)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 4.369271755218506
# training the data with NN with hidden-layer-size( 41,10)
# 0.5114754098360655 0.5386666666666666
# [[156   0]
#  [149   0]]
# Time used 4.166590690612793
# training the data with NN with hidden-layer-size( 41,11)
# 0.5114754098360655 0.5313333333333333
# [[156   0]
#  [149   0]]
# Time used 3.9026730060577393
# training the data with NN with hidden-layer-size( 41,12)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.8120315074920654
# training the data with NN with hidden-layer-size( 41,13)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.338017225265503
# training the data with NN with hidden-layer-size( 41,14)
# 0.5114754098360655 0.5233333333333333
# [[156   0]
#  [149   0]]
# Time used 2.2948360443115234
# training the data with NN with hidden-layer-size( 41,15)
# 0.5114754098360655 0.54
# [[156   0]
#  [149   0]]
# Time used 1.2722444534301758
# training the data with NN with hidden-layer-size( 41,16)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.6949484348297119
# training the data with NN with hidden-layer-size( 41,17)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.5146758556365967
# training the data with NN with hidden-layer-size( 41,18)
# 0.5114754098360655 0.542
# [[156   0]
#  [149   0]]
# Time used 1.2098863124847412
# training the data with NN with hidden-layer-size( 41,19)
# 0.5081967213114754 0.558
# [[151   5]
#  [145   4]]
# Time used 4.725194931030273
# training the data with NN with hidden-layer-size( 42,5)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.8611364364624023
# training the data with NN with hidden-layer-size( 42,6)
# 0.4885245901639344 0.466
# [[  0 156]
#  [  0 149]]
# Time used 3.4895057678222656
# training the data with NN with hidden-layer-size( 42,7)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 3.7227418422698975
# training the data with NN with hidden-layer-size( 42,8)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.452759027481079
# training the data with NN with hidden-layer-size( 42,9)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 0.8697988986968994
# training the data with NN with hidden-layer-size( 42,10)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.103353261947632
# training the data with NN with hidden-layer-size( 42,11)
# 0.5114754098360655 0.5720000000000001
# [[156   0]
#  [149   0]]
# Time used 1.6992700099945068
# training the data with NN with hidden-layer-size( 42,12)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 2.4508445262908936
# training the data with NN with hidden-layer-size( 42,13)
# 0.4885245901639344 0.5286666666666667
# [[  0 156]
#  [  0 149]]
# Time used 4.557772636413574
# training the data with NN with hidden-layer-size( 42,14)
# 0.5114754098360655 0.5393333333333333
# [[156   0]
#  [149   0]]
# Time used 1.1132192611694336
# training the data with NN with hidden-layer-size( 42,15)
# 0.5114754098360655 0.5426666666666666
# [[156   0]
#  [149   0]]
# Time used 1.084073781967163
# training the data with NN with hidden-layer-size( 42,16)
# 0.5114754098360655 0.5293333333333333
# [[156   0]
#  [149   0]]
# Time used 2.73140549659729
# training the data with NN with hidden-layer-size( 42,17)
# 0.5114754098360655 0.5233333333333333
# [[156   0]
#  [149   0]]
# Time used 2.043034553527832
# training the data with NN with hidden-layer-size( 42,18)
# 0.4885245901639344 0.5393333333333333
# [[  0 156]
#  [  0 149]]
# Time used 1.9306137561798096
# training the data with NN with hidden-layer-size( 42,19)
# 0.4885245901639344 0.5393333333333332
# [[  0 156]
#  [  0 149]]
# Time used 3.9271762371063232
# training the data with NN with hidden-layer-size( 43,5)
